# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# Any results you write to the current directory are saved as output.

# %%
import keras
# Out:
# Using TensorFlow backend.
# C:\Users\Patron\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Patron\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Patron\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Patron\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Patron\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Patron\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Patron\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Patron\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Patron\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Patron\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Patron\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Patron\anaconda3\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
from numpy import loadtxt
from keras.models import load_model
model = load_model("model-no-shuflle.final")
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\Patron\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
#
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional_2 (Bidirection (None, 11, 1024)          1579008
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 11, 1024)          4096
# _________________________________________________________________
# gru_4 (GRU)                  (None, 256)               983808
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 2,587,585
# Trainable params: 2,585,537
# Non-trainable params: 2,048
# _________________________________________________________________

# %%
train = pd.read_csv('train.csv', dtype={'acoustic_data': np.int16, 'time_to_failure': np.float32})

# %%
train_df = train
train_df.head(20)
# Out:
#     acoustic_data  time_to_failure
# 0              12           1.4691
# 1               6           1.4691
# 2               8           1.4691
# 3               5           1.4691
# 4               8           1.4691
# 5               8           1.4691
# 6               9           1.4691
# 7               7           1.4691
# 8              -5           1.4691
# 9               3           1.4691
# 10              5           1.4691
# 11              2           1.4691
# 12              2           1.4691
# 13              3           1.4691
# 14             -1           1.4691
# 15              5           1.4691
# 16              6           1.4691
# 17              4           1.4691
# 18              3           1.4691
# 19              5           1.4691

# %%
train_acoustic_data_small = train['acoustic_data'].values[::50]
train_time_to_failure_small = train['time_to_failure'].values[::50]

fig, ax1 = plt.subplots(figsize=(16, 8))
plt.title("Trends of seismic signal and time_to_failure")
plt.plot(train_acoustic_data_small, color='b')
ax1.set_ylabel('seismic signal', color='b')
plt.legend(['seismic signal'])
ax2 = ax1.twinx()
plt.plot(train_time_to_failure_small, color='g')
ax2.set_ylabel('time_to_failure', color='g')
plt.legend(['time_to_failure'], loc=(0.875, 0.9))
plt.grid(False)

del train_acoustic_data_small
del train_time_to_failure_small
# Out:
# C:\Users\Patron\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
fig, ax1 = plt.subplots(figsize=(16, 8))
plt.title("Trends of seismic signal and time_to_failure")
plt.plot(train['acoustic_data'].values[:12582910], color='b')
ax1.set_ylabel('seismic signal', color='b')
plt.legend(['seismic signal'])
ax2 = ax1.twinx()
plt.plot(train['time_to_failure'].values[:12582910], color='g')
ax2.set_ylabel('time_to_failure', color='g')
plt.legend(['time_to_failure'], loc=(0.875, 0.9))
plt.grid(False)
# Out:
# C:\Users\Patron\anaconda3\lib\site-packages\IPython\core\pylabtools.py:132: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
chunk_size = 150000

chunks = int(np.floor(train_df.shape[0]/chunk_size))

X_data = pd.DataFrame(index=range(chunks), dtype=np.float32, columns=['min','max','std', 'avg', 'sum', 'median', 'mean_diff', 
                                                                       'q05', 'q25', 'q75', 'q95'])
y_data = pd.DataFrame(index=range(chunks), dtype=np.float32, columns=['ttf'])

def create_features(data_chunk, X_df, chunk_no, col_name='acoustic_data'):
    x = data_chunk[col_name]
    X_df.loc[chunk_no, 'min'] = x.min()
    X_df.loc[chunk_no, 'max'] = x.max()
    X_df.loc[chunk_no, 'std'] = x.std()
    X_df.loc[chunk_no, 'avg'] = x.mean()
    X_df.loc[chunk_no, 'sum'] = x.sum()
    X_df.loc[chunk_no, 'median'] = x.median()
    X_df.loc[chunk_no, 'mean_diff'] = np.mean(np.diff(x))
    X_df.loc[chunk_no, 'q05'] = np.quantile(x, 0.05)
    X_df.loc[chunk_no, 'q25'] = np.quantile(x, 0.25)
    X_df.loc[chunk_no, 'q75'] = np.quantile(x, 0.75)
    X_df.loc[chunk_no, 'q95'] = np.quantile(x, 0.95)
    return X_df

# %%
from tqdm import tqdm
for chunk_no in tqdm(range(chunks)):
    data_chunk = train_df.iloc[chunk_no*chunk_size:chunk_no*chunk_size+chunk_size]
    X_data = create_features(data_chunk, X_data, chunk_no)
    y = data_chunk['time_to_failure'].values[-1]
    y_data.loc[chunk_no, 'ttf'] = y
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 4194/4194 [00:46<00:00, 90.72it/s]

# %%
print(X_data.shape)
print(y_data.shape)
print(X_data.shape[1])
X_data.head()
# Out:
# (4194, 11)
# (4194, 1)
# 11
#      min    max       std       avg       sum  median  mean_diff  q05  q25  \
# 0  -98.0  104.0  5.101106  4.884113  732617.0     5.0  -0.000080 -2.0  3.0
# 1 -154.0  181.0  6.588824  4.725767  708865.0     5.0   0.000000 -2.0  2.0
# 2 -106.0  140.0  6.967397  4.906394  735959.0     5.0  -0.000013 -3.0  2.0
# 3 -199.0  197.0  6.922305  4.902240  735336.0     5.0   0.000000 -2.0  2.0
# 4 -126.0  145.0  7.301110  4.908720  736308.0     5.0  -0.000007 -2.0  2.0
#
#    q75   q95
# 0  7.0  11.0
# 1  7.0  12.0
# 2  7.0  13.0
# 3  7.0  12.0
# 4  7.0  12.0

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_data.values, y_data.values, test_size=0.2)
# X_test
# X_data.values
X_train.shape
# Out:
# (3355, 11)

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, LSTM, Bidirectional, GRU
from keras.optimizers import adam
from keras.callbacks import ModelCheckpoint
from keras.layers.normalization import BatchNormalization


#keras.layers.GRU(units, activation='tanh', recurrent_activation='sigmoid', use_bias=True, kernel_initializer='glorot_uniform', recurrent_initializer='orthogonal', bias_initializer='zeros', kernel_regularizer=None, recurrent_regularizer=None, bias_regularizer=None, activity_regularizer=None, kernel_constraint=None, recurrent_constraint=None, bias_constraint=None, dropout=0.0, recurrent_dropout=0.0, implementation=2, return_sequences=False, return_state=False, go_backwards=False, stateful=False, unroll=False, reset_after=False)

model = Sequential()
model.add((GRU(512, kernel_initializer="RandomUniform", input_shape= (X_train.shape[1], 1), return_sequences = True,recurrent_dropout = 0.2)))
#model.add(CuDNNGRU(64, kernel_initializer="RandomUniform", input_shape= (X_train.shape[1], 1)))
model.add(BatchNormalization())
#model.add(Dropout(0.2))
model.add(GRU(256, recurrent_dropout = 0.3))
#model.add(Dropout(0.2))
model.add(Dense(64, activation="relu"))
#model.add(BatchNormalization())
#model.add(Dropout(0.2))
model.add(Dense(64, activation="relu"))
model.add(Dropout(0.20))
# model.add(Flatten())
model.add(Dense(1))

# %%
# Reshaping for fit
# X_train_array = np.reshape(X_train, (X_train.shape[0], 1, X_train.shape[1]))
X_train_array = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))
y_train_array = np.reshape(y_train, (y_train.shape[0], y_train.shape[1], 1))

print(X_train_array.shape)
print(y_train_array.shape)
# Out:
# (3355, 11, 1)
# (3355, 1, 1)

# %%
# model.compile(loss="mean_squared_error", optimizer="rmsprop", metrics=["mse"])
opt = keras.optimizers.Adam(learning_rate=1e-5)
model.compile(loss="mean_absolute_error", optimizer=opt, metrics=["mae", "mse"])
#model.summary()

build = model.fit(X_train_array, y_train, epochs=150, batch_size=30, validation_split = 0.20, verbose=1, shuffle = False)
# Out:
# Train on 2684 samples, validate on 671 samples
# Epoch 1/150
# 2684/2684 [==============================] - 23s 9ms/step - loss: 4.1919 - mae: 4.1919 - mse: 28.7094 - val_loss: 4.5781 - val_mae: 4.5781 - val_mse: 32.4325
# Epoch 2/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 3.1150 - mae: 3.1150 - mse: 15.8882 - val_loss: 3.5321 - val_mae: 3.5321 - val_mse: 20.4149
# Epoch 3/150
# 2684/2684 [==============================] - 20s 7ms/step - loss: 2.9021 - mae: 2.9021 - mse: 13.5103 - val_loss: 3.0794 - val_mae: 3.0794 - val_mse: 15.4211
# Epoch 4/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.8603 - mae: 2.8603 - mse: 13.0842 - val_loss: 2.9577 - val_mae: 2.9577 - val_mse: 14.0166
# Epoch 5/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.8215 - mae: 2.8215 - mse: 12.9838 - val_loss: 2.8963 - val_mae: 2.8963 - val_mse: 13.1918
# Epoch 6/150
# 2684/2684 [==============================] - 23s 9ms/step - loss: 2.8808 - mae: 2.8808 - mse: 13.4142 - val_loss: 2.8737 - val_mae: 2.8737 - val_mse: 12.8956
# Epoch 7/150
# 2684/2684 [==============================] - 25s 9ms/step - loss: 2.8424 - mae: 2.8424 - mse: 13.1624 - val_loss: 2.8642 - val_mae: 2.8642 - val_mse: 12.7709
# Epoch 8/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.8373 - mae: 2.8373 - mse: 12.8957 - val_loss: 2.8444 - val_mae: 2.8444 - val_mse: 12.5143
# Epoch 9/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.8290 - mae: 2.8290 - mse: 12.8009 - val_loss: 2.8374 - val_mae: 2.8374 - val_mse: 12.4172
# Epoch 10/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.8393 - mae: 2.8393 - mse: 12.8537 - val_loss: 2.8355 - val_mae: 2.8355 - val_mse: 12.4117
# Epoch 11/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7957 - mae: 2.7957 - mse: 12.5466 - val_loss: 2.8283 - val_mae: 2.8283 - val_mse: 12.3249
# Epoch 12/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7996 - mae: 2.7996 - mse: 12.7146 - val_loss: 2.8349 - val_mae: 2.8349 - val_mse: 12.4897
# Epoch 13/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7896 - mae: 2.7896 - mse: 12.5644 - val_loss: 2.8218 - val_mae: 2.8218 - val_mse: 12.3022
# Epoch 14/150
# 2684/2684 [==============================] - 22s 8ms/step - loss: 2.7840 - mae: 2.7840 - mse: 12.5063 - val_loss: 2.8120 - val_mae: 2.8120 - val_mse: 12.1731
# Epoch 15/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.8183 - mae: 2.8183 - mse: 12.7929 - val_loss: 2.8125 - val_mae: 2.8125 - val_mse: 12.2163
# Epoch 16/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7852 - mae: 2.7852 - mse: 12.4947 - val_loss: 2.7981 - val_mae: 2.7981 - val_mse: 12.0208
# Epoch 17/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7563 - mae: 2.7563 - mse: 12.4151 - val_loss: 2.7900 - val_mae: 2.7900 - val_mse: 11.9418
# Epoch 18/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7732 - mae: 2.7732 - mse: 12.3214 - val_loss: 2.7831 - val_mae: 2.7831 - val_mse: 11.8329
# Epoch 19/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7729 - mae: 2.7729 - mse: 12.4377 - val_loss: 2.7795 - val_mae: 2.7795 - val_mse: 11.8658
# Epoch 20/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7574 - mae: 2.7574 - mse: 12.3424 - val_loss: 2.7745 - val_mae: 2.7745 - val_mse: 11.8884
# Epoch 21/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7478 - mae: 2.7478 - mse: 12.2258 - val_loss: 2.7685 - val_mae: 2.7685 - val_mse: 11.8264
# Epoch 22/150
# 2684/2684 [==============================] - 22s 8ms/step - loss: 2.7433 - mae: 2.7433 - mse: 12.0852 - val_loss: 2.7605 - val_mae: 2.7605 - val_mse: 11.7457
# Epoch 23/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7431 - mae: 2.7431 - mse: 12.0897 - val_loss: 2.7570 - val_mae: 2.7570 - val_mse: 11.8113
# Epoch 24/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7480 - mae: 2.7480 - mse: 12.1490 - val_loss: 2.7504 - val_mae: 2.7504 - val_mse: 11.7609
# Epoch 25/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7296 - mae: 2.7296 - mse: 11.9842 - val_loss: 2.7368 - val_mae: 2.7368 - val_mse: 11.6211
# Epoch 26/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.6959 - mae: 2.6959 - mse: 11.7037 - val_loss: 2.7273 - val_mae: 2.7273 - val_mse: 11.5213
# Epoch 27/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7094 - mae: 2.7094 - mse: 11.9343 - val_loss: 2.7240 - val_mae: 2.7240 - val_mse: 11.5774
# Epoch 28/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7174 - mae: 2.7174 - mse: 12.0522 - val_loss: 2.7150 - val_mae: 2.7150 - val_mse: 11.5346
# Epoch 29/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7362 - mae: 2.7362 - mse: 12.1409 - val_loss: 2.7025 - val_mae: 2.7025 - val_mse: 11.4639
# Epoch 30/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.7062 - mae: 2.7062 - mse: 11.8617 - val_loss: 2.6972 - val_mae: 2.6972 - val_mse: 11.4856
# Epoch 31/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.6383 - mae: 2.6383 - mse: 11.3182 - val_loss: 2.6854 - val_mae: 2.6854 - val_mse: 11.4240
# Epoch 32/150
# 2684/2684 [==============================] - 22s 8ms/step - loss: 2.6301 - mae: 2.6301 - mse: 11.2019 - val_loss: 2.6656 - val_mae: 2.6656 - val_mse: 11.2946
# Epoch 33/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.6337 - mae: 2.6337 - mse: 11.2454 - val_loss: 2.6496 - val_mae: 2.6496 - val_mse: 11.2059
# Epoch 34/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.6375 - mae: 2.6375 - mse: 11.3049 - val_loss: 2.6402 - val_mae: 2.6402 - val_mse: 11.2275
# Epoch 35/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.6293 - mae: 2.6293 - mse: 11.3542 - val_loss: 2.6207 - val_mae: 2.6207 - val_mse: 11.1058
# Epoch 36/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.6027 - mae: 2.6027 - mse: 11.1919 - val_loss: 2.6005 - val_mae: 2.6005 - val_mse: 11.0359
# Epoch 37/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.5934 - mae: 2.5934 - mse: 11.0384 - val_loss: 2.6201 - val_mae: 2.6201 - val_mse: 11.3760
# Epoch 38/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.5508 - mae: 2.5508 - mse: 10.6661 - val_loss: 2.5541 - val_mae: 2.5541 - val_mse: 10.6484
# Epoch 39/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.5665 - mae: 2.5665 - mse: 10.8772 - val_loss: 2.5462 - val_mae: 2.5462 - val_mse: 10.6715
# Epoch 40/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.5208 - mae: 2.5208 - mse: 10.5556 - val_loss: 2.5546 - val_mae: 2.5546 - val_mse: 10.9222
# Epoch 41/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.5068 - mae: 2.5068 - mse: 10.4806 - val_loss: 2.5419 - val_mae: 2.5419 - val_mse: 10.8511
# Epoch 42/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.5231 - mae: 2.5231 - mse: 10.5512 - val_loss: 2.5214 - val_mae: 2.5214 - val_mse: 10.7171
# Epoch 43/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.4922 - mae: 2.4922 - mse: 10.2716 - val_loss: 2.5229 - val_mae: 2.5229 - val_mse: 10.7948
# Epoch 44/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.4688 - mae: 2.4688 - mse: 10.1381 - val_loss: 2.4757 - val_mae: 2.4757 - val_mse: 10.3544
# Epoch 45/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.4802 - mae: 2.4802 - mse: 10.1834 - val_loss: 2.4752 - val_mae: 2.4752 - val_mse: 10.4699
# Epoch 46/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.4523 - mae: 2.4523 - mse: 10.0361 - val_loss: 2.4611 - val_mae: 2.4611 - val_mse: 10.4182
# Epoch 47/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.4536 - mae: 2.4536 - mse: 10.0331 - val_loss: 2.4488 - val_mae: 2.4488 - val_mse: 10.3476
# Epoch 48/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.4071 - mae: 2.4071 - mse: 9.7840 - val_loss: 2.4114 - val_mae: 2.4114 - val_mse: 10.0212
# Epoch 49/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.3830 - mae: 2.3830 - mse: 9.5690 - val_loss: 2.4210 - val_mae: 2.4210 - val_mse: 10.1952
# Epoch 50/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.3813 - mae: 2.3813 - mse: 9.5385 - val_loss: 2.4157 - val_mae: 2.4157 - val_mse: 10.2006
# Epoch 51/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.3733 - mae: 2.3733 - mse: 9.5823 - val_loss: 2.3976 - val_mae: 2.3976 - val_mse: 10.0843
# Epoch 52/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.3662 - mae: 2.3662 - mse: 9.6014 - val_loss: 2.3666 - val_mae: 2.3666 - val_mse: 9.8339
# Epoch 53/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.3422 - mae: 2.3422 - mse: 9.3232 - val_loss: 2.3622 - val_mae: 2.3622 - val_mse: 9.8123
# Epoch 54/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.3631 - mae: 2.3631 - mse: 9.5001 - val_loss: 2.3571 - val_mae: 2.3571 - val_mse: 9.7973
# Epoch 55/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.3596 - mae: 2.3596 - mse: 9.3893 - val_loss: 2.3539 - val_mae: 2.3539 - val_mse: 9.7836
# Epoch 56/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.3134 - mae: 2.3134 - mse: 9.0793 - val_loss: 2.3507 - val_mae: 2.3507 - val_mse: 9.7706
# Epoch 57/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.3278 - mae: 2.3278 - mse: 9.2560 - val_loss: 2.3495 - val_mae: 2.3495 - val_mse: 9.7659
# Epoch 58/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2991 - mae: 2.2991 - mse: 8.8591 - val_loss: 2.3332 - val_mae: 2.3332 - val_mse: 9.6456
# Epoch 59/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2725 - mae: 2.2725 - mse: 8.8349 - val_loss: 2.3197 - val_mae: 2.3197 - val_mse: 9.5467
# Epoch 60/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.3187 - mae: 2.3187 - mse: 9.2123 - val_loss: 2.3087 - val_mae: 2.3087 - val_mse: 9.4687
# Epoch 61/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2764 - mae: 2.2764 - mse: 8.7961 - val_loss: 2.3278 - val_mae: 2.3278 - val_mse: 9.6324
# Epoch 62/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2990 - mae: 2.2990 - mse: 8.8930 - val_loss: 2.3067 - val_mae: 2.3067 - val_mse: 9.4835
# Epoch 63/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2861 - mae: 2.2861 - mse: 8.8870 - val_loss: 2.2931 - val_mae: 2.2931 - val_mse: 9.3853
# Epoch 64/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2712 - mae: 2.2712 - mse: 8.8139 - val_loss: 2.3119 - val_mae: 2.3119 - val_mse: 9.5279
# Epoch 65/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2870 - mae: 2.2870 - mse: 8.8934 - val_loss: 2.3393 - val_mae: 2.3393 - val_mse: 9.7435
# Epoch 66/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2705 - mae: 2.2705 - mse: 8.8226 - val_loss: 2.3118 - val_mae: 2.3118 - val_mse: 9.5425
# Epoch 67/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2840 - mae: 2.2840 - mse: 8.9555 - val_loss: 2.3514 - val_mae: 2.3514 - val_mse: 9.8451
# Epoch 68/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2878 - mae: 2.2878 - mse: 8.8139 - val_loss: 2.3237 - val_mae: 2.3237 - val_mse: 9.6494
# Epoch 69/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2578 - mae: 2.2578 - mse: 8.7618 - val_loss: 2.2692 - val_mae: 2.2692 - val_mse: 9.2498
# Epoch 70/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2504 - mae: 2.2504 - mse: 8.7200 - val_loss: 2.2509 - val_mae: 2.2509 - val_mse: 9.1189
# Epoch 71/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2306 - mae: 2.2306 - mse: 8.5489 - val_loss: 2.2917 - val_mae: 2.2917 - val_mse: 9.4325
# Epoch 72/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2533 - mae: 2.2533 - mse: 8.7863 - val_loss: 2.2820 - val_mae: 2.2820 - val_mse: 9.3585
# Epoch 73/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2350 - mae: 2.2350 - mse: 8.5217 - val_loss: 2.2713 - val_mae: 2.2713 - val_mse: 9.2845
# Epoch 74/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2394 - mae: 2.2394 - mse: 8.6077 - val_loss: 2.2987 - val_mae: 2.2987 - val_mse: 9.5092
# Epoch 75/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2619 - mae: 2.2619 - mse: 8.8165 - val_loss: 2.3525 - val_mae: 2.3525 - val_mse: 9.9205
# Epoch 76/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2426 - mae: 2.2426 - mse: 8.6315 - val_loss: 2.2681 - val_mae: 2.2681 - val_mse: 9.2899
# Epoch 77/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2409 - mae: 2.2409 - mse: 8.5995 - val_loss: 2.3262 - val_mae: 2.3262 - val_mse: 9.7307
# Epoch 78/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2490 - mae: 2.2490 - mse: 8.7536 - val_loss: 2.2737 - val_mae: 2.2737 - val_mse: 9.3440
# Epoch 79/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2335 - mae: 2.2335 - mse: 8.5629 - val_loss: 2.2690 - val_mae: 2.2690 - val_mse: 9.3167
# Epoch 80/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2292 - mae: 2.2292 - mse: 8.6975 - val_loss: 2.2852 - val_mae: 2.2852 - val_mse: 9.4432
# Epoch 81/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2254 - mae: 2.2254 - mse: 8.5327 - val_loss: 2.2842 - val_mae: 2.2842 - val_mse: 9.4440
# Epoch 82/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2047 - mae: 2.2047 - mse: 8.4409 - val_loss: 2.2310 - val_mae: 2.2310 - val_mse: 9.0334
# Epoch 83/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2107 - mae: 2.2107 - mse: 8.5179 - val_loss: 2.2607 - val_mae: 2.2607 - val_mse: 9.2698
# Epoch 84/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2184 - mae: 2.2184 - mse: 8.4566 - val_loss: 2.2444 - val_mae: 2.2444 - val_mse: 9.1508
# Epoch 85/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2149 - mae: 2.2149 - mse: 8.5674 - val_loss: 2.2121 - val_mae: 2.2121 - val_mse: 8.8794
# Epoch 86/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.1945 - mae: 2.1945 - mse: 8.3648 - val_loss: 2.2307 - val_mae: 2.2307 - val_mse: 9.0324
# Epoch 87/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2196 - mae: 2.2196 - mse: 8.5467 - val_loss: 2.2183 - val_mae: 2.2183 - val_mse: 8.9403
# Epoch 88/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2135 - mae: 2.2135 - mse: 8.5117 - val_loss: 2.2332 - val_mae: 2.2332 - val_mse: 9.0729
# Epoch 89/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2199 - mae: 2.2199 - mse: 8.5167 - val_loss: 2.2759 - val_mae: 2.2759 - val_mse: 9.4173
# Epoch 90/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2358 - mae: 2.2358 - mse: 8.6468 - val_loss: 2.2486 - val_mae: 2.2486 - val_mse: 9.1970
# Epoch 91/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2276 - mae: 2.2276 - mse: 8.5023 - val_loss: 2.2669 - val_mae: 2.2669 - val_mse: 9.3490
# Epoch 92/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2105 - mae: 2.2105 - mse: 8.5481 - val_loss: 2.2306 - val_mae: 2.2306 - val_mse: 9.0563
# Epoch 93/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2051 - mae: 2.2051 - mse: 8.4801 - val_loss: 2.2275 - val_mae: 2.2275 - val_mse: 9.0393
# Epoch 94/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2083 - mae: 2.2083 - mse: 8.4485 - val_loss: 2.2089 - val_mae: 2.2089 - val_mse: 8.8900
# Epoch 95/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2123 - mae: 2.2123 - mse: 8.5137 - val_loss: 2.2262 - val_mae: 2.2262 - val_mse: 9.0367
# Epoch 96/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2031 - mae: 2.2031 - mse: 8.3331 - val_loss: 2.2151 - val_mae: 2.2151 - val_mse: 8.9432
# Epoch 97/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2269 - mae: 2.2269 - mse: 8.5949 - val_loss: 2.2417 - val_mae: 2.2417 - val_mse: 9.1684
# Epoch 98/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1912 - mae: 2.1912 - mse: 8.3186 - val_loss: 2.2388 - val_mae: 2.2388 - val_mse: 9.1495
# Epoch 99/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1949 - mae: 2.1949 - mse: 8.4441 - val_loss: 2.2067 - val_mae: 2.2067 - val_mse: 8.8932
# Epoch 100/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2097 - mae: 2.2097 - mse: 8.4093 - val_loss: 2.2087 - val_mae: 2.2087 - val_mse: 8.9027
# Epoch 101/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1759 - mae: 2.1759 - mse: 8.2435 - val_loss: 2.2344 - val_mae: 2.2344 - val_mse: 9.1058
# Epoch 102/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2085 - mae: 2.2085 - mse: 8.5112 - val_loss: 2.2181 - val_mae: 2.2181 - val_mse: 8.9684
# Epoch 103/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2078 - mae: 2.2078 - mse: 8.2891 - val_loss: 2.1985 - val_mae: 2.1985 - val_mse: 8.8084
# Epoch 104/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1827 - mae: 2.1827 - mse: 8.2504 - val_loss: 2.2102 - val_mae: 2.2102 - val_mse: 8.9019
# Epoch 105/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1904 - mae: 2.1904 - mse: 8.2516 - val_loss: 2.2027 - val_mae: 2.2027 - val_mse: 8.8457
# Epoch 106/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2045 - mae: 2.2045 - mse: 8.4286 - val_loss: 2.1848 - val_mae: 2.1848 - val_mse: 8.6997
# Epoch 107/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.1940 - mae: 2.1940 - mse: 8.3239 - val_loss: 2.1924 - val_mae: 2.1924 - val_mse: 8.7640
# Epoch 108/150
# 2684/2684 [==============================] - 22s 8ms/step - loss: 2.2106 - mae: 2.2106 - mse: 8.5016 - val_loss: 2.1826 - val_mae: 2.1826 - val_mse: 8.6804
# Epoch 109/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2063 - mae: 2.2063 - mse: 8.3910 - val_loss: 2.1679 - val_mae: 2.1679 - val_mse: 8.5596
# Epoch 110/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1877 - mae: 2.1877 - mse: 8.2486 - val_loss: 2.1870 - val_mae: 2.1870 - val_mse: 8.7260
# Epoch 111/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1930 - mae: 2.1930 - mse: 8.3666 - val_loss: 2.2090 - val_mae: 2.2090 - val_mse: 8.9172
# Epoch 112/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1972 - mae: 2.1972 - mse: 8.3893 - val_loss: 2.1868 - val_mae: 2.1868 - val_mse: 8.7307
# Epoch 113/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1988 - mae: 2.1988 - mse: 8.2480 - val_loss: 2.2116 - val_mae: 2.2116 - val_mse: 8.9417
# Epoch 114/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2106 - mae: 2.2106 - mse: 8.4442 - val_loss: 2.1824 - val_mae: 2.1824 - val_mse: 8.7050
# Epoch 115/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2120 - mae: 2.2120 - mse: 8.2580 - val_loss: 2.1744 - val_mae: 2.1744 - val_mse: 8.6341
# Epoch 116/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.1780 - mae: 2.1780 - mse: 8.2548 - val_loss: 2.1768 - val_mae: 2.1768 - val_mse: 8.6479
# Epoch 117/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1983 - mae: 2.1983 - mse: 8.3858 - val_loss: 2.1890 - val_mae: 2.1890 - val_mse: 8.7536
# Epoch 118/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.1985 - mae: 2.1985 - mse: 8.3072 - val_loss: 2.1888 - val_mae: 2.1888 - val_mse: 8.7514
# Epoch 119/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1875 - mae: 2.1875 - mse: 8.3476 - val_loss: 2.1996 - val_mae: 2.1996 - val_mse: 8.8452
# Epoch 120/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1748 - mae: 2.1748 - mse: 8.3264 - val_loss: 2.1812 - val_mae: 2.1812 - val_mse: 8.6958
# Epoch 121/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1734 - mae: 2.1734 - mse: 8.2020 - val_loss: 2.1852 - val_mae: 2.1852 - val_mse: 8.7342
# Epoch 122/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1881 - mae: 2.1881 - mse: 8.3107 - val_loss: 2.1449 - val_mae: 2.1449 - val_mse: 8.3867
# Epoch 123/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2138 - mae: 2.2138 - mse: 8.4759 - val_loss: 2.1703 - val_mae: 2.1703 - val_mse: 8.6023
# Epoch 124/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2151 - mae: 2.2151 - mse: 8.4774 - val_loss: 2.1730 - val_mae: 2.1730 - val_mse: 8.6266
# Epoch 125/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1822 - mae: 2.1822 - mse: 8.3502 - val_loss: 2.1700 - val_mae: 2.1700 - val_mse: 8.6064
# Epoch 126/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1895 - mae: 2.1895 - mse: 8.3188 - val_loss: 2.1661 - val_mae: 2.1661 - val_mse: 8.5714
# Epoch 127/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1934 - mae: 2.1934 - mse: 8.2782 - val_loss: 2.1601 - val_mae: 2.1601 - val_mse: 8.5198
# Epoch 128/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2005 - mae: 2.2005 - mse: 8.4087 - val_loss: 2.1732 - val_mae: 2.1732 - val_mse: 8.6356
# Epoch 129/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1687 - mae: 2.1687 - mse: 8.2611 - val_loss: 2.1735 - val_mae: 2.1735 - val_mse: 8.6418
# Epoch 130/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1997 - mae: 2.1997 - mse: 8.3167 - val_loss: 2.1515 - val_mae: 2.1515 - val_mse: 8.4352
# Epoch 131/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2034 - mae: 2.2034 - mse: 8.4833 - val_loss: 2.1677 - val_mae: 2.1677 - val_mse: 8.5853
# Epoch 132/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1992 - mae: 2.1992 - mse: 8.3698 - val_loss: 2.1552 - val_mae: 2.1552 - val_mse: 8.4759
# Epoch 133/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1821 - mae: 2.1821 - mse: 8.2634 - val_loss: 2.1704 - val_mae: 2.1704 - val_mse: 8.6165
# Epoch 134/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.1888 - mae: 2.1888 - mse: 8.2374 - val_loss: 2.1595 - val_mae: 2.1595 - val_mse: 8.5196
# Epoch 135/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1903 - mae: 2.1903 - mse: 8.3637 - val_loss: 2.1522 - val_mae: 2.1522 - val_mse: 8.4540
# Epoch 136/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2032 - mae: 2.2032 - mse: 8.4522 - val_loss: 2.1560 - val_mae: 2.1560 - val_mse: 8.4897
# Epoch 137/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2045 - mae: 2.2045 - mse: 8.5604 - val_loss: 2.1818 - val_mae: 2.1818 - val_mse: 8.7123
# Epoch 138/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1886 - mae: 2.1886 - mse: 8.3849 - val_loss: 2.1573 - val_mae: 2.1573 - val_mse: 8.5004
# Epoch 139/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1815 - mae: 2.1815 - mse: 8.2002 - val_loss: 2.1610 - val_mae: 2.1610 - val_mse: 8.5330
# Epoch 140/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.1743 - mae: 2.1743 - mse: 8.2055 - val_loss: 2.1687 - val_mae: 2.1687 - val_mse: 8.6035
# Epoch 141/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1835 - mae: 2.1835 - mse: 8.2868 - val_loss: 2.1427 - val_mae: 2.1427 - val_mse: 8.3594
# Epoch 142/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1795 - mae: 2.1795 - mse: 8.2278 - val_loss: 2.1330 - val_mae: 2.1330 - val_mse: 8.2681
# Epoch 143/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1988 - mae: 2.1988 - mse: 8.4047 - val_loss: 2.1556 - val_mae: 2.1556 - val_mse: 8.4775
# Epoch 144/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1930 - mae: 2.1930 - mse: 8.3367 - val_loss: 2.1585 - val_mae: 2.1585 - val_mse: 8.5012
# Epoch 145/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1975 - mae: 2.1975 - mse: 8.3806 - val_loss: 2.1506 - val_mae: 2.1506 - val_mse: 8.4284
# Epoch 146/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1952 - mae: 2.1952 - mse: 8.3524 - val_loss: 2.1412 - val_mae: 2.1412 - val_mse: 8.3446
# Epoch 147/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.2131 - mae: 2.2131 - mse: 8.5004 - val_loss: 2.1658 - val_mae: 2.1658 - val_mse: 8.5689
# Epoch 148/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1873 - mae: 2.1873 - mse: 8.3258 - val_loss: 2.1573 - val_mae: 2.1573 - val_mse: 8.4936
# Epoch 149/150
# 2684/2684 [==============================] - 20s 8ms/step - loss: 2.1883 - mae: 2.1883 - mse: 8.3837 - val_loss: 2.1451 - val_mae: 2.1451 - val_mse: 8.3811
# Epoch 150/150
# 2684/2684 [==============================] - 21s 8ms/step - loss: 2.2087 - mae: 2.2087 - mse: 8.3971 - val_loss: 2.1421 - val_mae: 2.1421 - val_mse: 8.3551

# %%
import locale
locale.setlocale(locale.LC_ALL, '')
code = locale.getpreferredencoding()

# %%
import sys
import numpy
numpy.set_printoptions(threshold=sys.maxsize)

# %%
import pydot
import os

from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
SVG(model_to_dot(model,show_shapes = True).create(prog='dot', format='svg'))

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.vis_utils import plot_model
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.vis_utils import plot_model
plot_model(model, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru_3 (GRU)                  (None, 11, 512)           789504
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 11, 512)           2048
# _________________________________________________________________
# gru_4 (GRU)                  (None, 256)               590592
# _________________________________________________________________
# dense_4 (Dense)              (None, 64)                16448
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                4160
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 1,402,817
# Trainable params: 1,401,793
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
import matplotlib.pyplot as plt
# list all data in history
print(build.history.keys())
# summarize history for accuracy
plt.plot(build.history['mae'])
plt.plot(build.history['val_mae'])
plt.title('model MAE')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(build.history['loss'])
plt.plot(build.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_mae', 'val_mse', 'loss', 'mae', 'mse'])

# %%
model.save("model-no-shuflle.final")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
submission = pd.read_csv("sample_submission.csv", index_col='seg_id', dtype={"time_to_failure": np.float32})
X_sub = pd.DataFrame(columns=X_data.columns, dtype=np.float32)

for i, seg_id in enumerate(tqdm(submission.index)):
    seg = pd.read_csv('test/' + str(seg_id) + '.csv')
    X_seg = create_features(seg, X_sub, i)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2624/2624 [01:58<00:00, 22.23it/s]

# %%
X_seg_array = np.reshape(X_seg.values, (X_seg.shape[0], X_seg.shape[1], 1))
pred_final = model.predict(X_seg_array)
submission['time_to_failure'] = pred_final

submission.to_csv('submission-LSTM.csv')

# %%
possible_eq = submission.loc[submission["time_to_failure"] < 1.0]
print(possible_eq)
print(type(possible_eq))
print(possible_eq.columns)
# segments = ["seg_26a2a0", "seg_724df9", "seg_7a9f2b", "seg_7fa6ec", "seg_aa98cc", "seg_b35174", "seg_c80857", "seg_e3d751"]

for seg_id in possible_eq.index:
    print(seg_id)
    seg = pd.read_csv('test/' + seg_id + '.csv')
    fig, ax1 = plt.subplots(figsize=(8, 4))
    plt.title("Trends of acoustic_data for test file {}".format(seg_id))
    plt.plot(seg['acoustic_data'].values, color='b')
    ax1.set_ylabel('acoustic_data', color='b')
    plt.legend(['acoustic_data'])
# Out:
#             time_to_failure
# seg_id
# seg_004314         0.849007
# seg_26a2a0         0.313333
# seg_2f86cd         0.473670
# seg_39ad50         0.775455
# seg_3e87b4         0.923489
# seg_724df9         0.263926
# seg_7848f8         0.356415
# seg_7a9f2b         0.343983
# seg_7fa6ec         0.308729
# seg_aa98cc         0.311698
# seg_b35174         0.319333
# seg_b686e5         0.803519
# seg_bfdd14         0.878438
# seg_c243a6         0.996716
# seg_c5dee4         0.980307
# seg_c80857         0.286766
# seg_e3d751         0.236633
# <class 'pandas.core.frame.DataFrame'>
# Index(['time_to_failure'], dtype='object')
# seg_004314
# seg_26a2a0
# seg_2f86cd
# seg_39ad50
# seg_3e87b4
# seg_724df9
# seg_7848f8
# seg_7a9f2b
# seg_7fa6ec
# seg_aa98cc
# seg_b35174
# seg_b686e5
# seg_bfdd14
# seg_c243a6
# seg_c5dee4
# seg_c80857
# seg_e3d751

# %%
import dill
#dill.dump_session('notebook_env.db')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-35-0d291198e13b> in <module>
# ----> 1 import dill
#       2 #dill.dump_session('notebook_env.db')
#
# ModuleNotFoundError: No module named 'dill'
